# %%
import argparse
import logging
import re
from pathlib import Path
import pandas as pd

class SamplingStrategy:
    def __init__(self, inputPath, outputPath, annotationFilePath):
        self.inputPath = inputPath
        self.outputPath = outputPath
        self.annotationFilePath = annotationFilePath

    
    def stratifiedSampling(self):
        df = pd.read_csv(self.annotationFilePath)
        
        print(df.head())

        for i in df.index:
            print(df.iloc[[i],])
        
            



strat = SamplingStrategy("self", "self", "../data/fall_simulation_data/high_quality_fall_annotations.csv")

strat.stratifiedSampling()
# Out:
#    scenario_id category  fall_start  fall_end  lying_start  lying_end  length  \
# 0            1     Fall        47.0      50.0         50.0      125.0     138
# 1            2     Fall        97.0     100.0        100.0      248.0     270
# 2            3     Fall       128.0     131.0        131.0      224.0     235
# 3            4     Fall        95.0      96.0         96.0      195.0     235
# 4            5     Fall        32.0      34.0         34.0      216.0     235
#
#   fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 0               True               True               True  ...
# 1               True               True               True  ...
# 2               True               True               True  ...
# 3               True               True               True  ...
# 4               True               True               True  ...
#
#   lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 0                True                True                True
# 1                True                True                True
# 2                True                True                True
# 3                True                True                True
# 4                True                True                True
#
#   lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 0                True                True           5.0           2.0
# 1                True                True           4.0           1.0
# 2                True                True           5.0           2.0
# 3                True                True           4.0           2.0
# 4                True                True           5.0           1.0
#
#    ranking_cam_3  ranking_cam_4  ranking_cam_5
# 0            3.0            1.0            4.0
# 1            3.0            2.0            5.0
# 2            3.0            1.0            4.0
# 3            3.0            1.0            5.0
# 4            4.0            2.0            3.0
#
# [5 rows x 22 columns]
#    scenario_id category  fall_start  fall_end  lying_start  lying_end  length  \
# 0            1     Fall        47.0      50.0         50.0      125.0     138
#
#   fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 0               True               True               True  ...
#
#   lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 0                True                True                True
#
#   lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 0                True                True           5.0           2.0
#
#    ranking_cam_3  ranking_cam_4  ranking_cam_5
# 0            3.0            1.0            4.0
#
# [1 rows x 22 columns]
#    scenario_id category  fall_start  fall_end  lying_start  lying_end  length  \
# 1            2     Fall        97.0     100.0        100.0      248.0     270
#
#   fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 1               True               True               True  ...
#
#   lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 1                True                True                True
#
#   lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 1                True                True           4.0           1.0
#
#    ranking_cam_3  ranking_cam_4  ranking_cam_5
# 1            3.0            2.0            5.0
#
# [1 rows x 22 columns]
#    scenario_id category  fall_start  fall_end  lying_start  lying_end  length  \
# 2            3     Fall       128.0     131.0        131.0      224.0     235
#
#   fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 2               True               True               True  ...
#
#   lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 2                True                True                True
#
#   lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 2                True                True           5.0           2.0
#
#    ranking_cam_3  ranking_cam_4  ranking_cam_5
# 2            3.0            1.0            4.0
#
# [1 rows x 22 columns]
#    scenario_id category  fall_start  fall_end  lying_start  lying_end  length  \
# 3            4     Fall        95.0      96.0         96.0      195.0     235
#
#   fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 3               True               True               True  ...
#
#   lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 3                True                True                True
#
#   lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 3                True                True           4.0           2.0
#
#    ranking_cam_3  ranking_cam_4  ranking_cam_5
# 3            3.0            1.0            5.0
#
# [1 rows x 22 columns]
#    scenario_id category  fall_start  fall_end  lying_start  lying_end  length  \
# 4            5     Fall        32.0      34.0         34.0      216.0     235
#
#   fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 4               True               True               True  ...
#
#   lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 4                True                True                True
#
#   lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 4                True                True           5.0           1.0
#
#    ranking_cam_3  ranking_cam_4  ranking_cam_5
# 4            4.0            2.0            3.0
#
# [1 rows x 22 columns]
#    scenario_id category  fall_start  fall_end  lying_start  lying_end  length  \
# 5            6     Fall        44.0      47.0         47.0      238.0     255
#
#   fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 5               True               True               True  ...
#
#   lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 5                True                True                True
#
#   lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 5                True                True           5.0           1.0
#
#    ranking_cam_3  ranking_cam_4  ranking_cam_5
# 5            4.0            2.0            3.0
#
# [1 rows x 22 columns]
#    scenario_id category  fall_start  fall_end  lying_start  lying_end  length  \
# 6            7     Fall        28.0      31.0         31.0      219.0     230
#
#   fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 6               True               True               True  ...
#
#   lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 6                True                True                True
#
#   lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 6                True                True           3.0           4.0
#
#    ranking_cam_3  ranking_cam_4  ranking_cam_5
# 6            1.0            2.0            5.0
#
# [1 rows x 22 columns]
#    scenario_id category  fall_start  fall_end  lying_start  lying_end  length  \
# 7            8     Fall        79.0      82.0         82.0      188.0     200
#
#   fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 7               True               True               True  ...
#
#   lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 7                True                True                True
#
#   lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 7                True                True           3.0           4.0
#
#    ranking_cam_3  ranking_cam_4  ranking_cam_5
# 7            2.0            5.0            1.0
#
# [1 rows x 22 columns]
#    scenario_id category  fall_start  fall_end  lying_start  lying_end  length  \
# 8            9     Fall        78.0      80.0         80.0      203.0     224
#
#   fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 8               True               True               True  ...
#
#   lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 8                True                True                True
#
#   lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 8                True                True           2.0           5.0
#
#    ranking_cam_3  ranking_cam_4  ranking_cam_5
# 8            1.0            4.0            3.0
#
# [1 rows x 22 columns]
#    scenario_id category  fall_start  fall_end  lying_start  lying_end  length  \
# 9           10     Fall        23.0      25.0         25.0      168.0     180
#
#   fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 9               True               True               True  ...
#
#   lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 9                True                True                True
#
#   lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 9                True                True           2.0           4.0
#
#    ranking_cam_3  ranking_cam_4  ranking_cam_5
# 9            5.0            1.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 10           11     Fall        52.0      54.0         54.0       60.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 10     145               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 10                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 10                True                True           4.0           3.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 10            2.0            1.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 11           12     Fall        16.0      18.0         18.0       71.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 11      72               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 11                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 11                True                True           4.0           3.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 11            1.0            5.0            2.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 12           13     Fall        24.0      27.0         27.0       94.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 12     110               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 12               False                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 12                True               False           4.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 12            3.0            2.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 13           14     Fall        11.0      13.0         13.0      220.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 13     255               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 13                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 13                True                True           3.0           4.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 13            1.0            2.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 14           15     Fall        10.0      12.0         12.0      103.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 14     110               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 14                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 14                True                True           3.0           4.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 14            1.0            2.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 15           16     Fall        12.0      15.0         15.0      177.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 15     190               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 15                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 15                True                True           4.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 15            5.0            2.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 16           17     Fall        14.0      16.0         16.0      112.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 16     124               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 16                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 16                True                True           3.0           4.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 16            1.0            2.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 17           18     Fall        88.0      91.0         91.0      243.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 17     255               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 17                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 17                True                True           1.0           2.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 17            4.0            5.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 18           19     Fall        55.0      58.0         58.0      225.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 18     240               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 18                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 18                True                True           1.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 18            2.0            4.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 19           20     Fall        84.0      86.0         86.0       91.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 19     240               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 19                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 19                True                True           1.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 19            2.0            3.0            4.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 20           21     Fall        49.0      51.0         51.0      160.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 20     160               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 20                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 20                True                True           4.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 20            5.0            2.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 21           22     Fall        19.0      22.0         22.0      127.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 21     145               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 21                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 21                True                True           4.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 21            5.0            2.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 22           23     Fall        16.0      19.0         19.0      110.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 22     126               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 22                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 22                True                True           5.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 22            3.0            2.0            4.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 23           24     Fall        30.0      33.0         33.0       97.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 23     130               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 23                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 23                True                True           5.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 23            3.0            2.0            4.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 24           25     Fall        23.0      25.0         25.0       96.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 24     110               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 24                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 24                True                True           2.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 24            1.0            4.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 25           26     Fall        15.0      18.0         18.0      106.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 25     110               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 25                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 25                True                True           1.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 25            3.0            4.0            2.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 26           27     Fall        67.0      70.0         70.0      121.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 26     140               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 26                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 26                True                True           5.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 26            4.0            2.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 27           28     Fall        68.0      70.0         70.0      134.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 27     150               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 27                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 27                True                True           2.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 27            3.0            4.0            1.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 28           29     Fall        23.0      25.0         25.0       37.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 28     120               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 28                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 28                True                True           5.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 28            4.0            2.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 29           30     Fall        24.0      27.0         27.0       88.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 29     110               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 29                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 29                True                True           4.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 29            3.0            2.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 30           31     Fall        65.0      67.0         67.0      158.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 30     180               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 30                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 30                True                True           3.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 30            2.0            4.0            1.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 31           32     Fall        53.0      55.0         55.0      144.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 31     174               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 31                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 31                True                True           3.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 31            2.0            4.0            1.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 32           33     Fall        28.0      30.0         30.0      200.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 32     225               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 32                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 32                True                True           5.0           4.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 32            2.0            1.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 33           34     Fall        25.0      28.0         28.0      241.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 33     265               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 33                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 33                True                True           5.0           3.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 33            1.0            4.0            2.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 34           35     Fall        29.0      32.0         32.0      230.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 34     245               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 34                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 34                True                True           2.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 34            3.0            4.0            1.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 35           36     Fall        32.0      34.0         34.0      175.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 35     245               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 35                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 35                True                True           4.0           3.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 35            2.0            1.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 36           37     Fall        30.0      33.0         33.0       88.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 36     110               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 36                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 36                True                True           2.0           4.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 36            1.0            5.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 37           38     Fall        24.0      26.0         26.0       78.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 37      90               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 37                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 37                True                True           4.0           2.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 37            5.0            1.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 38           39     Fall        30.0      32.0         32.0       86.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 38     110               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 38                True               False                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 38               False               False           1.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 38            2.0            4.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 39           40     Fall        53.0      55.0         55.0      115.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 39     140               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 39                True               False                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 39                True                True           2.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 39            1.0            3.0            4.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 40           41     Fall        39.0      42.0         42.0       95.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 40     140               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 40                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 40                True                True           2.0           4.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 40            3.0            5.0            1.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 41           42     Fall        79.0      81.0         81.0       92.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 41     140               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 41                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 41                True                True           4.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 41            2.0            3.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 42           43     Fall        64.0      66.0         66.0      106.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 42     145               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 42                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 42                True                True           2.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 42            1.0            4.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 43           44     Fall        26.0      28.0         28.0       31.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 43     110               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 43                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 43                True                True           2.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 43            3.0            4.0            1.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 44           45     Fall        20.0      22.0         22.0       28.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 44      50               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 44                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 44                True                True           4.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 44            3.0            2.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 45           46     Fall        26.0      28.0         28.0       39.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 45      60               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 45               False                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 45                True                True           5.0           2.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 45            4.0            1.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 46           47     Fall        25.0      28.0         28.0       39.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 46      55               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 46                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 46                True                True           4.0           3.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 46            1.0            2.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 47           48     Fall        32.0      34.0         34.0       47.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 47      70               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 47                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 47                True                True           4.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 47            2.0            3.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 48           49     Fall        24.0      26.0         26.0      123.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 48     145               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 48                True                True               False
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 48                True                True           4.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 48            5.0            2.0            3.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 49           50     Fall        15.0      18.0         18.0      131.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 49     140               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 49                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 49                True                True           3.0           2.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 49            4.0            1.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 50           51     Fall        28.0      31.0         31.0      140.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 50     150               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 50                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 50                True                True           2.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 50            3.0            4.0            1.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 51           52     Fall        43.0      45.0         45.0      164.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 51     180               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 51                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 51                True                True           4.0           2.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 51            3.0            1.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 52           53     Fall        71.0      73.0         73.0      214.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 52     220               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 52                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 52                True                True           1.0           5.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 52            3.0            4.0            2.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 53           54     Fall        43.0      46.0         46.0      184.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 53     205               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 53                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 53                True                True           4.0           1.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 53            2.0            3.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 54           55     Fall        29.0      32.0         32.0      164.0
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 54     180               True               True               True  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 54                True                True                True
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 54                True               False           1.0           4.0
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 54            3.0            2.0            5.0
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 55            1      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 55    1800                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 55                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 55                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 55            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 56            2      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 56    1335                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 56                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 56                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 56            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 57            3      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 57     740                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 57                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 57                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 57            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 58            4      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 58     828                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 58                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 58                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 58            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 59            5      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 59     698                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 59                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 59                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 59            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 60            6      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 60    1490                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 60                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 60                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 60            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 61            7      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 61    1528                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 61                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 61                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 61            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 62            8      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 62     880                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 62                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 62                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 62            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 63            9      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 63    1140                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 63                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 63                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 63            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 64           10      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 64    1170                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 64                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 64                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 64            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 65           11      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 65    2130                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 65                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 65                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 65            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 66           12      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 66    1420                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 66                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 66                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 66            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 67           13      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 67     860                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 67                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 67                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 67            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 68           14      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 68    1450                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 68                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 68                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 68            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 69           15      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 69    1165                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 69                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 69                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 69            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 70           16      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 70     840                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 70                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 70                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 70            NaN            NaN            NaN
#
# [1 rows x 22 columns]
#     scenario_id category  fall_start  fall_end  lying_start  lying_end  \
# 71           17      ADL         NaN       NaN          NaN        NaN
#
#     length fall_visible_cam_1 fall_visible_cam_2 fall_visible_cam_3  ...  \
# 71    1875                NaN                NaN                NaN  ...
#
#    lying_visible_cam_1 lying_visible_cam_2 lying_visible_cam_3  \
# 71                 NaN                 NaN                 NaN
#
#    lying_visible_cam_4 lying_visible_cam_5 ranking_cam_1 ranking_cam_2  \
# 71                 NaN                 NaN           NaN           NaN
#
#     ranking_cam_3  ranking_cam_4  ranking_cam_5
# 71            NaN            NaN            NaN
#
# [1 rows x 22 columns]
